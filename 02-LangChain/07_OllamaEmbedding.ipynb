# %%
from langchain_ollama import OllamaEmbeddings

# %%
embeddings = (
    OllamaEmbeddings(model="nomic-embed-text")
)

# %%
r1 = embeddings.embed_documents(
    [
        "Alpha is the first charcater of greek aplhabet",
        "Beta is the second charcater of greek aplhabet"
    ]
)

# %%
r1
# Out:
# [[-0.0069290227,
#   0.011852357,
#   -0.1823188,
#   -0.079309195,
#   0.059912086,
#   -0.008657689,
#   -0.039913587,
#   0.038444065,
#   -0.030570608,
#   0.010801238,
#   -0.03545549,
#   0.062109824,
#   0.07575368,
#   0.060614355,
#   0.01226757,
#   -0.060973737,
#   -0.0016559489,
#   -0.04548199,
#   -0.029364552,
#   0.01528503,
#   -0.016186828,
#   -0.050668713,
#   -0.005613915,
#   -0.025548324,
#   0.09624185,
#   0.013386253,
#   -0.018579703,
#   0.0028222732,
#   -0.021740204,
#   -0.062728494,
#   0.014926395,
#   -0.028369652,
#   0.048512492,
#   0.0071326867,
#   0.033691593,
#   -0.008205852,
#   -0.0022516474,
#   0.083723016,
#   0.018258184,
#   -0.008334001,
#   -0.04281383,
#   0.0141139375,
#   0.032152325,
#   -0.004912969,
#   0.011967665,
#   -0.029478325,
#   0.008596193,
#   0.0010348464,
#   0.048730645,
#   -0.0024223386,
#   -0.0010245831,
#   -0.035490856,
#   -0.029065996,
#   -0.04508556,
#   0.03416577,
#   0.028005669,
#   0.041442122,
# ...

# %%
len(r1[0])
# Out:
# 768

# %%
embeddings.embed_query("what is the second letter of greek alphabet")
# Out:
# [0.020766445,
#  0.0007143767,
#  -0.12903309,
#  -0.07131949,
#  0.07977783,
#  -0.03527752,
#  -0.048198715,
#  0.00030367356,
#  -0.016035546,
#  -0.013967297,
#  -0.05368058,
#  0.12313193,
#  0.059671115,
#  0.010436538,
#  0.031503696,
#  -0.05450416,
#  0.027329689,
#  -0.0339077,
#  -0.050501883,
#  0.004201715,
#  -0.037537735,
#  -0.021332942,
#  -0.013354973,
#  -0.02596634,
#  0.09915375,
#  0.07228204,
#  0.087378025,
#  0.03776761,
#  -0.025411,
#  -0.053597093,
#  -0.042169873,
#  -0.014996472,
#  0.049844794,
#  -0.06663875,
#  0.011493611,
#  0.015073372,
#  -0.015427814,
#  0.049292862,
#  0.0076611997,
#  -0.007617516,
#  -0.023745012,
#  -0.053550597,
#  -0.0058520357,
#  0.023622232,
#  0.047573715,
#  -0.070787184,
#  -0.060907856,
#  0.071171165,
#  0.022971705,
#  -0.059641562,
#  0.047456954,
#  -0.00023007949,
#  -0.007158248,
#  0.01462041,
#  -0.023283862,
#  0.009366757,
#  0.029363373,
#  -0.024005286,
#  0.04379956,
#  0.008789842,
#  0.027410379,
# ...

# %% [markdown]
# There are several embedding models in ollama

# %% [markdown]
# we can explore all models by visiting [ollama](https://ollama.com/blog/embedding-models)

# %% [markdown]
# models like mxbai-embed-large, nomic-embed-text, all-minilm
