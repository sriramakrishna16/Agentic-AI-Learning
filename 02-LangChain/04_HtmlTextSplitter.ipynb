# %%
from langchain_text_splitters import HTMLHeaderTextSplitter

html_string = """
<html>
  <body>
    <h1>Artificial Intelligence</h1>
    <p>
      Artificial Intelligence (AI) is a field of computer science focused on building systems that can perform tasks requiring human intelligence.
    </p>

    <h2>Machine Learning</h2>
    <p>
      Machine Learning is a subset of AI that enables systems to learn from data and improve over time without explicit programming.
    </p>

    <h3>Supervised Learning</h3>
    <p>
      Supervised learning uses labeled datasets to train models for classification and regression tasks.
    </p>

    <h3>Unsupervised Learning</h3>
    <p>
      Unsupervised learning finds hidden patterns in data without labeled outputs.
    </p>

    <h2>Deep Learning</h2>
    <p>
      Deep learning uses neural networks with many layers to model complex patterns in large datasets.
    </p>
  </body>
</html>
"""

headers_to_split_on = [
    ("h1","header 1"),
    ("h2", "header 2"),
    ("h3", "header 3")
]

html_splitter = HTMLHeaderTextSplitter(headers_to_split_on=headers_to_split_on)
html_header_splits = html_splitter.split_text(html_string)
html_header_splits
# Out:
# [Document(metadata={'header 1': 'Artificial Intelligence'}, page_content='Artificial Intelligence'),
#  Document(metadata={'header 1': 'Artificial Intelligence'}, page_content='Artificial Intelligence (AI) is a field of computer science focused on building systems that can perform tasks requiring human intelligence.'),
#  Document(metadata={'header 1': 'Artificial Intelligence', 'header 2': 'Machine Learning'}, page_content='Machine Learning'),
#  Document(metadata={'header 1': 'Artificial Intelligence', 'header 2': 'Machine Learning'}, page_content='Machine Learning is a subset of AI that enables systems to learn from data and improve over time without explicit programming.'),
#  Document(metadata={'header 1': 'Artificial Intelligence', 'header 2': 'Machine Learning', 'header 3': 'Supervised Learning'}, page_content='Supervised Learning'),
# ...

# %% [markdown]
# url HtmlHeaderSplitter

# %%
url = "https://plato.stanford.edu/entries/plato/"

headers_to_split_on = [
    ("h1","Header 1"),
    ("h2", "Header 2"),
    ("h3", "Header 3"),
    ("h4", "Header 4")
]

html_splitter2 = HTMLHeaderTextSplitter(headers_to_split_on=headers_to_split_on)

html_header_splits_url = html_splitter2.split_text_from_url(url)

html_header_splits_url
# Out:
# [Document(metadata={}, page_content='End container NOTE: Script required for drop-down button to work (mirrors).  \nEnd header wrapper End content End footer  \nEnd header  \nEnd navigation End search  \nStanford Encyclopedia of Philosophy  \nMenu  \nBrowse  \nTable of Contents  \nWhat\'s New  \nRandom Entry  \nChronological  \nArchives  \nAbout  \nEditorial Information  \nAbout the SEP  \nEditorial Board  \nHow to Cite the SEP  \nSpecial Characters  \nAdvanced Tools  \nContact  \nSupport SEP  \nSupport the SEP  \nPDFs for SEP Friends  \nMake a Donation  \nSEPIA for Libraries  \nBegin article sidebar End article sidebar NOTE: Article content must have two wrapper divs: id="article" and id="article-content" End article NOTE: article banner is outside of the id="article" div. End article-banner  \nEntry Navigation  \nEntry Contents  \nBibliography  \nAcademic Tools  \nFriends PDF Preview  \nAuthor and Citation Info  \nBack to Top  \nEnd article-content  \nBEGIN ARTICLE HTML #aueditable
# ...
